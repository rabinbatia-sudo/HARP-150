# %% [markdown]
# <a href="https://colab.research.google.com/github/rabinbatia-sudo/HARP-150/blob/main/Notes_9_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Debugging and Python

# %%
#python is very adaptive, can import a lot of packages and libraries, easy for beginners
#very good at data analysis, quick language
#open source
#github, collab for coders, share code
#reddit python subreddit
#most common errors: syntax, name, key, type

#exception handling, except clause, try clause, finally clause, try:, except:, finally:
#helps to premptively fix errors
#if the try code has an error it will not be executed and be skipped and instead do the except clause
#if the try code works than it will execute the finally clause

# %%
#error code 1
name = "Batia"
age = " 19"
print(name + age)
# Out:
# Batia 19

# %%
#error code 2
6/2
# Out:
# 3.0
