# %% [markdown]
# <a href="https://colab.research.google.com/github/rabinbatia-sudo/HARP-150/blob/main/Game_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Batia Rabin and Lexine Egypto
#Who Killed Anna? is a murder mystery, the player or detective has to choose five objects to look at for clues
#and guess who killed Anna.

import time

detective = input("What is your name? ")
clues = {"diary": "Anna's Diary: 'I haven't been feeling safe these past few days . . . I feel like I'm being followed and watched . . . I think I keep seeing a man.'",
         "bullet": "Bullet from a glock: It seems that Anna was murdered by being shot"}
# Out:
# What is your name? lexine

# %%
def intro():
  time.sleep(3)
  print("𝖂𝖍𝖔 𝕶𝖎𝖑𝖑𝖊𝖉 𝕬𝖓𝖆?")
  detective_greeting = (f"Hello Detective, {detective}")
  print("This is the scene of the crime, the room Anna was murdered in, what clues can you find?")
  print("")
  print("These objects are in the room: a diary, bullet, broken vase, T.V., phone, muddy footprints, couch, food, glass of wine, and remote.")
  print("")
  print("You may only choose five clues. Choose wisely detective "+detective+ ".")
  print("")

# %%
def call_objects():
  print("Type the name of the object to find out more about it.")
  object_1 = input("Object 1: ")
  object_2 = input("Object 2: ")
  object_3 = input("Object 3: ")
  object_4 = input("Object 4: ")
  object_5 = input("Object 5: ")
# Out:
#   File "<ipython-input-4-e8a70479fadd>", line 3
#     print("Type the name of the object to find out more about it.")
#         ^
# IndentationError: expected an indented block
