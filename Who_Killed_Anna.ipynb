# %% [markdown]
# <a href="https://colab.research.google.com/github/rabinbatia-sudo/HARP-150/blob/main/Who_Killed_Anna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Batia Rabin and Lexine Egypto
#Who Killed Anna? is a murder mystery, the player or detective has to choose five objects to look at for clues and guess who killed Anna.

import time # importing time to make time module available in code
! pip install python-cfonts # installing third-party package to add in our code,  for the title of our game
from cfonts import render, say # importing the package

print("--------------------------------------------------------------------------------------------------------------")
print("")

output = render('Who Killed Anna?', colors = ['red', 'yellow'], align ='center', size = (90,100), max_length = 0) # editing the title of our game
detective = input("What is your name? ") # asking player for their name to use later and to make the game more personalized
play_again = "yes"
clues = {"diary": "Anna's Diary: 'I haven't been feeling safe these past few days . . . I feel like I'm being followed and watched . . . I think I keep seeing a man.'", # the dictionary is used to store information for use in the game
         "bullet": "Bullet from a glock: It seems that Anna was murdered by being shot",
         "broken vase": "Anna's Vase: It seems like there was a struggle between Anna and her assailant.",
         "tv": "Anna's TV: There is a crime documentary playing. The TV is cracked . . . there seems to have been a struggle.",
         "phone": "Anna's Phone: 'Just because you're the oldest doesn't mean you deserve to inherit all of grandma's money! If you don't give me some of the money, I'm coming for you!'",
         "muddy footprints": "A man's footprints: It didn't rain yesterday yet it seems there are footprints from boots . . .",
         "couch": "Bloodsplatter: It seems like Anna was shot on the couch.",
         "food": "Leftovers from lunch: There is food in the fridge that seems to be leftovers from Bell and Anna's lunch.",
         "wine": "Two glasses of wine: It seems Anna drank a bottle of vintage wine with someone before she was killed.",
         "remote": "Anna's remote: Fingerprints on the remote match to Brianna's . . ."}
objects = ["diary", "bullet", "broken vase", "tv", "phone", "muddy footprints", "couch", "food", "wine", "remote"]

def intro(): # introduction function of our game
  print("")
  print("--------------------------------------------------------------------------------------------------------------")
  print("")
  print("Anna was killed at her house, specifically in her living room on Friday the 13th at 12:00 AM.")
  print("")
  time.sleep(2) # used to make lines of code appear slower
  print("She was in line to inherit 200 million dollars from grandmother, Cecilia.")
  print("")
  time.sleep(2)
  print("Anna has three younger siblings, who are now eligible to inherit the money.")
  print("")
  time.sleep(2)
  print("Their names are: Bell, Billy, Brianna.")
  print("")
  time.sleep(2)
  print("Bell is the youngest. He is a police officer who enjoys cooking and gardening.")
  print("")
  time.sleep(2)
  print("Billy is the third child. He works as a bartender and enjoys playing video gamesin his free time.")
  print("")
  time.sleep(2)
  print("Brianna is the second eldest. She is a bank teller and enjoys reading as well as watching documentaries.")
  print("")
  print("")
  time.sleep(2)
  print ("₮ⱧɆ Đ₳Ɏ ฿Ɇ₣ØⱤɆ ₳₦₦₳ ĐłɆĐ...")
  print("")
  time.sleep(2)
  print("Bell was seen visiting Anna for lunch that day.")
  print("")
  time.sleep(2)
  print("There was a threatening voicemail on Anna's phone from Billy.")
  print("")
  time.sleep(2)
  print("Brianna and Anna were seen arguing on Anna's porch.")
  print("--------------------------------------------------------------------------------------------------------------")
def clues_intro(): # this function is where the player is oriented on what the available clues are
  print (output)
  print("")
  time.sleep(2)
  detective_greeting = (f"Hello Detective, {detective}")
  print("")
  time.sleep(2)
  print("This is the scene of the crime. What clues can you find?")
  print("")
  time.sleep(2)
  print("These objects are in the room: a diary, bullet, broken vase, TV, phone, muddy footprints, couch, food, wine, and a remote.")
  print("")
  time.sleep(2)
  print("You may only choose five objects to find more about. Choose wisely detective "+ detective + ".")
  print("")

def call_clues(): # this function relays the clues to the player
  count = 5 # player can only choose 5 clues
  your_objects = [] # an empty list to store the 5 clues the player whishes to choose
  global objects # make the list called objects accessible or useable in this function
  while count != 0: # while loop for the process of the player selecting objects
    print("")
    print("These objects are in the room:", objects)
    print("To click on an object and learn more about it enter the name of the object. You have", count, "objects left")
    print("")
    click_on = input("What object would you like to choose? ").lower()
    if click_on in your_objects: # to avoid selecting a clue that the player has chosen
      print("")
      print("You have aready clicked on this object.")
      click_on = input("What object would you like to choose? ").lower()
      count -= 1 # after inputing the obejct of your choice, your number of choices is subtracted by 1
    elif click_on not in objects: # if the object they chose isn't in the list of objects available they will be asked to input a new object
      print("")
      print("This is not an object in the room.")
      click_on = input("What object would you like to choose? ").lower()  # in case a player makes a typographic error, the player will be notified and will be asked to choose an object in the list shown
      count -= 1
    else: # if or once player has selected an object from the list of objects, it will be added to the list 'your_objects' and the number of objects they can choose will be subtracted by one
      your_objects.append(click_on)
      count -= 1
    if click_on in clues.keys(): # the clue for the object that the player has selected will be printed for the player to see
      print("┃" +clues[click_on]+"┃")
      print("")

def end(): # this function is the ending of the game
  global play_again # make the variable called play_again accessible or useable in this function
  killer = input("Who do you think is the killer? Enter the name of one of the siblings to choose. ").lower()
  if killer == "billy": # if player inputs "billy" the player wins the game
    print("")
    print("Congrats you found the killer. Thanks for playing! 🥳")
    play_again = "no" # game ends once player inputs "billy"
  elif killer == "brianna" or killer == "bell":
    print("")
    print("You sent the wrong person to jail.") # if player did not input the correct answer this statement will be printed out
    play_again = input("Do you want to play again? Enter yes or no. ").lower() # player loses the game if they input the wrong answer and will be asked if they want to play again
    print("")
  else:
    print("This person is not one of the choices.")  # when player makes a typographic error or inputs a random answer, this statement will pop up
    killer = input("Who do you think is the killer? Enter the name of one of the siblings to choose. ").lower()

while play_again == "yes": # while play again is yes the game will continue to run, if it is changed to no while running the end function, the game will end
  intro()
  clues_intro()
  call_clues()
  end()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# --------------------------------------------------------------------------------------------------------------
#
# What is your name? lex
#
# --------------------------------------------------------------------------------------------------------------
#
# Anna was killed at her house, specifically in her living room on Friday the 13th at 12:00 AM.
#
# She was in line to inherit 200 million dollars from grandmother, Cecilia.
#
# Anna has three younger siblings, who are now eligible to inherit the money.
#
# Their names are: Bell, Billy, Brianna.
#
# Bell is the youngest. He is a police officer who enjoys cooking and gardening.
#
# Billy is the third child. He works as a bartender and enjoys playing video gamesin his free time.
#
# Brianna is the second eldest. She is a bank teller and enjoys reading as well as watching documentaries.
#
#
# ₮ⱧɆ Đ₳Ɏ ฿Ɇ₣ØⱤɆ ₳₦₦₳ ĐłɆĐ...
#
# ...

# %% [markdown]
# https://pypi.org/project/python-cfonts/
#
#  https://exoticfonts.com/creepy-text-generator/
