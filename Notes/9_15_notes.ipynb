# %% [markdown]
# <a href="https://colab.research.google.com/github/rabinbatia-sudo/HARP-150/blob/main/9_15_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#What distinguishes python from other languages?
#General purpose language, many uses
#Fortran is the first commercially available language
#Ranked as the top most popular programming language
#Will be using object oriented programming
#There are interpreted and compiled languages
#High-level language, high and far away from machine hardware
#Very good for beginners, easy to learn, very readable to code, intuitive, looks most like english, open source, huge community of developers
#Python gets its meaning from indentation, not brackets
#Does many things implicitly, don't need to identify type
#Most common syntax errors: wrong indentation, punctuation, spelling
#Operators - math symbols

# %%
alphabet = 4
alphabet is 4
#is, isnot can be used to check if things are equal
# Out:
# True

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
#Review of lab 2
#Line 1 - string
#Line 2 - comment
#Line 3 - float
#Line 4 - boolean
#Line 6 - print function/method
#Line 8 - variable
#Line 11 - length function
#Line 13 - modulo, gives remainder

# %%
#input function, asks user to give you input, the variable type is string
#type cast, converting one type into another, int(), float(), str()
#can't concatanate an integer, only string
